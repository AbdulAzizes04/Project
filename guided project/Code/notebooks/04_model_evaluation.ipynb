# %% [markdown]
# # Notebook 04: Model Evaluation & Comparison
# **GuidedGuard – Explainable AI for Scam-Guided Digital Payment Detection**
#
# ### Objectives:
# - Evaluate trained models using comprehensive classification metrics:
#   - Accuracy, Precision, Recall, F1-Score
#   - Area Under ROC Curve (ROC-AUC)
#   - Area Under Precision-Recall Curve (PR-AUC)
# - Generate & plot Confusion Matrices.
# - Select the best-performing model.
# - Serialize and save best model (`models/saved_model.pkl`) and scaler (`models/scaler.pkl`).

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, precision_recall_curve, auc, confusion_matrix, classification_report
)
import joblib
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))
import config

print("Evaluation libraries imported.")

# %% [markdown]
# ## 1. Metric Calculation Function

# %%
def evaluate_model(model, X_test, y_test, model_name="Model"):
    """Calculate performance metrics for a given model."""
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:, 1]
    
    precision, recall, _ = precision_recall_curve(y_test, y_proba)
    pr_auc = auc(recall, precision)
    
    metrics = {
        "Model": model_name,
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred),
        "Recall": recall_score(y_test, y_pred),
        "F1-Score": f1_score(y_test, y_pred),
        "ROC-AUC": roc_auc_score(y_test, y_proba),
        "PR-AUC": pr_auc
    }
    return metrics

# %% [markdown]
# ## 2. Serialize Best Model & Scaler Artifacts

# %%
# Example serialization block
# joblib.dump(best_model, config.SAVED_MODEL_PATH)
# joblib.dump(scaler, config.SCALER_PATH)
print(f"Target Model Path: {config.SAVED_MODEL_PATH}")
print(f"Target Scaler Path: {config.SCALER_PATH}")
